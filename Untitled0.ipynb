# %%
def pig_latin(x):
  vowels=['a', 'e', 'i', 'o', 'u']
  if x[0] in vowels:
    print(x+'way')
  else:
    print(x[1:]+x[0]+'ay')

# %%
pig_latin('dumbass')
# Out:
# umbassday

# %%
def pig_latin_sentence(x):
  words=x.split()
  translation=[]
  for x in words:
    if x[0] in 'aeiou':
      translation.append(x+'way')
    else:
      translation.append(x[1:]+x[0]+'ay')
  result=' '.join(translation)
  return result

# %%
pig_latin_sentence('if you want the shots i will take the staff job double the money')
# Out:
# 'ifway ouyay antway hetay hotssay iway illway aketay hetay taffsay objay oubleday hetay oneymay'

# %%
sentence='this is a test'

# %%
sentence.split()
# Out:
# ['this', 'is', 'a', 'test']
